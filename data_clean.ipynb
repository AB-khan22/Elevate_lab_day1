# %% [markdown]
# import_libraries

# %%
import numpy as np 
import pandas as pd

# %%
#import dataset
df=pd.read_csv('messy_healthcare_noshows_appt.csv')

# %%
#show dataset
df.head(100)
# Out:
#        PatientId  Appt_ID Gender ScheduledDay AppointmentDay   Age  \
# 0   2.987250e+13  5642903      f   29-04-2016     29-04-2016  62.0
# 1   5.589980e+14  5642503      m   29-04-2016     29-04-2016  56.0
# 2   4.262960e+12  5642549      f   29-04-2016     29-04-2016  62.0
# 3   8.679510e+11  5642828      f   29-04-2016     29-04-2016   NaN
# 4   8.841190e+12  5642494    NaN   29-04-2016     29-04-2016  56.0
# ..           ...      ...    ...          ...            ...   ...
# 95  4.225490e+13  5634093      f   28-04-2016     29-04-2016  54.0
# 96  3.715430e+11  5639379      f   29-04-2016     29-04-2016  50.0
# 97  2.921560e+12  5639399      m   29-04-2016     29-04-2016   NaN
# 98  4.439510e+14  5639773      m   29-04-2016     29-04-2016  54.0
# 99  7.954400e+12  5608249      f   20-04-2016     29-04-2016  26.0
#
#           Neighbrhood  Scholarship  Hypertension  Diabetes  Alcoholism  \
# 0     JARDIM DA PENHA        False          True     False       False
# ...

# %%
df.shape
# Out:
# (107087, 17)

# %%
#check infomation of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107087 entries, 0 to 107086
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       107087 non-null  float64
#  1   Appt_ID         107087 non-null  int64
#  2   Gender          101734 non-null  object
#  3   ScheduledDay    107087 non-null  object
#  4   AppointmentDay  107087 non-null  object
#  5   Age             101733 non-null  float64
#  6   Neighbrhood     101734 non-null  object
#  7   Scholarship     107087 non-null  bool
#  8   Hypertension    107087 non-null  bool
#  9   Diabetes        107087 non-null  bool
#  10  Alcoholism      107087 non-null  bool
#  11  Handycap        107087 non-null  bool
#  12  SMS_received    107087 non-null  bool
#  13  Showed_up       107087 non-null  bool
#  14  Date_diff       107087 non-null  int64
#  15  Random_Notes    10709 non-null   object
#  16  Extra_Info      80403 non-null   object
# ...

# %%
df['Age']=df['Age'].astype(int)

# %%
df['ScheduledDay']=pd.to_datetime(df['ScheduledDay'])
df['AppointmentDay']=pd.to_datetime(df['AppointmentDay'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8244\218814972.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['ScheduledDay']=pd.to_datetime(df['ScheduledDay'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 df['ScheduledDay']=pd.to_datetime(df['ScheduledDay'])
#       2 df['AppointmentDay']=pd.to_datetime(df['AppointmentDay'])
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107087 entries, 0 to 107086
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       107087 non-null  float64
#  1   Appt_ID         107087 non-null  int64
#  2   Gender          101734 non-null  object
#  3   ScheduledDay    107087 non-null  object
#  4   AppointmentDay  107087 non-null  object
#  5   Age             101733 non-null  float64
#  6   Neighbrhood     101734 non-null  object
#  7   Scholarship     107087 non-null  bool
#  8   Hypertension    107087 non-null  bool
#  9   Diabetes        107087 non-null  bool
#  10  Alcoholism      107087 non-null  bool
#  11  Handycap        107087 non-null  bool
#  12  SMS_received    107087 non-null  bool
#  13  Showed_up       107087 non-null  bool
#  14  Date_diff       107087 non-null  int64
#  15  Random_Notes    10709 non-null   object
#  16  Extra_Info      80403 non-null   object
# ...

# %%
#calculate null values
df.isnull().sum()
# Out:
# PatientId             0
# Appt_ID               0
# Gender             5353
# ScheduledDay          0
# AppointmentDay        0
# Age                5354
# Neighbrhood        5353
# Scholarship           0
# Hypertension          0
# Diabetes              0
# Alcoholism            0
# Handycap              0
# SMS_received          0
# Showed_up             0
# Date_diff             0
# Random_Notes      96378
# Extra_Info        26684
# dtype: int64

# %%
#drop unusable and too messy columns
df.drop(['Random_Notes','Extra_Info'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# PatientId            0
# Appt_ID              0
# Gender            5353
# ScheduledDay         0
# AppointmentDay       0
# Age               5354
# Neighbrhood       5353
# Scholarship          0
# Hypertension         0
# Diabetes             0
# Alcoholism           0
# Handycap             0
# SMS_received         0
# Showed_up            0
# Date_diff            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107087 entries, 0 to 107086
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       107087 non-null  float64
#  1   Appt_ID         107087 non-null  int64
#  2   Gender          101734 non-null  object
#  3   ScheduledDay    107087 non-null  object
#  4   AppointmentDay  107087 non-null  object
#  5   Age             101733 non-null  float64
#  6   Neighbrhood     101734 non-null  object
#  7   Scholarship     107087 non-null  bool
#  8   Hypertension    107087 non-null  bool
#  9   Diabetes        107087 non-null  bool
#  10  Alcoholism      107087 non-null  bool
#  11  Handycap        107087 non-null  bool
#  12  SMS_received    107087 non-null  bool
#  13  Showed_up       107087 non-null  bool
#  14  Date_diff       107087 non-null  int64
# dtypes: bool(7), float64(2), int64(2), object(4)
# memory usage: 7.3+ MB

# %%
#drop NA     rows from dataset
df.dropna(axis=0,inplace=True)

# %%
df.head(20)
# Out:
#        PatientId  Appt_ID Gender ScheduledDay  AppointmentDay   Age  \
# 0   2.987250e+13  5642903      f   29-04-2016      29-04-2016  62.0
# 1   5.589980e+14  5642503      m   29-04-2016      29-04-2016  56.0
# 2   4.262960e+12  5642549      f   29-04-2016      29-04-2016  62.0
# 5   9.598510e+13  5626772      f   27-04-2016      29-04-2016  76.0
# 6   7.336880e+14  5630279      f   27-04-2016      29-04-2016  23.0
# 7   3.449830e+12  5630575      f   27-04-2016      29-04-2016  39.0
# 8   5.639470e+13  5638447      f   29-04-2016      29-04-2016  21.0
# 9   7.812460e+13  5629123      f   04-29-2016      29-04-2016  19.0
# 10  7.345360e+14  5630213      f   27-04-2016      29-04-2016  30.0
# 11  7.542950e+12  5620163      m   26-04-2016      29-04-2016  29.0
# 12  5.666550e+14  5634718      f   28-04-2016      29-04-2016  22.0
# 14  9.988470e+13  5633951      f   28-04-2016  April 29, 2016  54.0
# 15  9.994839e+10  5620206      f   26-04-2016      29-04-2016  15.0
# ...

# %%
a=df['Neighbrhood'].unique()
a=pd.DataFrame(a)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       81 non-null     object
# dtypes: object(1)
# memory usage: 780.0+ bytes

# %%
df.duplicated().sum()
# Out:
# np.int64(88)

# %%
df.drop_duplicates()
# Out:
#            PatientId  Appt_ID Gender ScheduledDay AppointmentDay   Age  \
# 0       2.987250e+13  5642903      f   29-04-2016     29-04-2016  62.0
# 1       5.589980e+14  5642503      m   29-04-2016     29-04-2016  56.0
# 2       4.262960e+12  5642549      f   29-04-2016     29-04-2016  62.0
# 5       9.598510e+13  5626772      f   27-04-2016     29-04-2016  76.0
# 6       7.336880e+14  5630279      f   27-04-2016     29-04-2016  23.0
# ...              ...      ...    ...          ...            ...   ...
# 106981  3.635530e+13  5651072      f   03-05-2016     07-06-2016  53.0
# 106982  2.572130e+12  5651768      f   03-05-2016     07-06-2016  56.0
# 106983  3.596270e+12  5650093      f   03-05-2016     07-06-2016  51.0
# 106985  9.213490e+13  5630323      f   27-04-2016     07-06-2016  38.0
# 106986  3.775120e+14  5629448      f   27-04-2016     07-06-2016  54.0
#
#             Neighbrhood  Scholarship  Hypertension  Diabetes  Alcoholism  \
# ...

# %%
df.reset_index()
# Out:
#         index     PatientId  Appt_ID Gender ScheduledDay AppointmentDay   Age  \
# 0           0  2.987250e+13  5642903      f   29-04-2016     29-04-2016  62.0
# 1           1  5.589980e+14  5642503      m   29-04-2016     29-04-2016  56.0
# 2           2  4.262960e+12  5642549      f   29-04-2016     29-04-2016  62.0
# 3           5  9.598510e+13  5626772      f   27-04-2016     29-04-2016  76.0
# 4           6  7.336880e+14  5630279      f   27-04-2016     29-04-2016  23.0
# ...       ...           ...      ...    ...          ...            ...   ...
# 91870  107081  7.746120e+14  5421947      f   02-03-2016     20-05-2016  61.0
# 91871  107082  6.119680e+11  5722303      f   20-05-2016     25-05-2016  16.0
# 91872  107083  7.552970e+13  5723230      f   20-05-2016     20-05-2016  42.0
# 91873  107084  9.559250e+13  5639968      f   29-04-2016     25-05-2016  43.0
# 91874  107085  2.451680e+11  5632626      f   28-04-2016     04-05-2016  34.0
#
# ...

# %%
df.head()
# Out:
#       PatientId  Appt_ID Gender ScheduledDay AppointmentDay   Age  \
# 0  2.987250e+13  5642903      f   29-04-2016     29-04-2016  62.0
# 1  5.589980e+14  5642503      m   29-04-2016     29-04-2016  56.0
# 2  4.262960e+12  5642549      f   29-04-2016     29-04-2016  62.0
# 5  9.598510e+13  5626772      f   27-04-2016     29-04-2016  76.0
# 6  7.336880e+14  5630279      f   27-04-2016     29-04-2016  23.0
#
#        Neighbrhood  Scholarship  Hypertension  Diabetes  Alcoholism  Handycap  \
# 0  JARDIM DA PENHA        False          True     False       False     False
# 1  JARDIM DA PENHA        False         False     False       False     False
# 2    MATA DA PRAIA        False         False     False       False     False
# 5        REPÚBLICA        False          True     False       False     False
# 6       GOIABEIRAS        False         False     False       False     False
#
#    SMS_received  Showed_up  Date_diff
# 0         False       True          0
# ...

# %%
df.shape
# Out:
# (91875, 15)

# %%
#export file 
df.to_csv('cleaned_data.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91875 entries, 0 to 107085
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientId       91875 non-null  float64
#  1   Appt_ID         91875 non-null  int64
#  2   Gender          91875 non-null  object
#  3   ScheduledDay    91875 non-null  object
#  4   AppointmentDay  91875 non-null  object
#  5   Age             91875 non-null  int64
#  6   Neighbrhood     91875 non-null  object
#  7   Scholarship     91875 non-null  bool
#  8   Hypertension    91875 non-null  bool
#  9   Diabetes        91875 non-null  bool
#  10  Alcoholism      91875 non-null  bool
#  11  Handycap        91875 non-null  bool
#  12  SMS_received    91875 non-null  bool
#  13  Showed_up       91875 non-null  bool
#  14  Date_diff       91875 non-null  int64
# dtypes: bool(7), float64(1), int64(3), object(4)
# memory usage: 6.9+ MB
